# %%
import pandas as pd

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder. \
master("local[4]"). \
appName("Dataframe-Giriş"). \
config("spark.driver.memory","2g"). \
config("spark.executor.memory","4g"). \
getOrCreate()

# %%
sc = spark.sparkContext

# %% [markdown]
# # listeden DF

# %%
from pyspark.sql import Row
list_rdd = sc.parallelize([1,2,3,4,5,6,5,4]). \
map(lambda x: Row(x))

# %%
df_from_list = list_rdd.toDF(["rakamlar"])

# %%
df_from_list.show()
# Out:
# +--------+
# |rakamlar|
# +--------+
# |       1|
# |       2|
# |       3|
# |       4|
# |       5|
# |       6|
# |       5|
# |       4|
# +--------+

# %% [markdown]
# # range ile DF

# %%
df_from_range = sc.parallelize(range(10,100,5)). \
map(lambda x: (x,)). \
toDF(["range"])

# %%
df_from_range.show(3)
# Out:
# +-----+
# |range|
# +-----+
# |   10|
# |   15|
# |   20|
# +-----+
# only showing top 3 rows

# %%
from pyspark.sql.types import IntegerType
df_from_range2 = spark.createDataFrame(range(10,100,5), IntegerType())

# %% [markdown]
# # Dosyadan DF

# %%
df_from_file = spark.read.csv("D:\\Datasets\\OnlineRetail.csv")

# %%
df_from_file.show()
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |InvoiceNo;StockCo...|
# |536365;85123A;WHI...|
# |536365;71053;WHIT...|
# |536365;84406B;CRE...|
# |536365;84029G;KNI...|
# |536365;84029E;RED...|
# |536365;22752;SET ...|
# |536365;21730;GLAS...|
# |536366;22633;HAND...|
# |536366;22632;HAND...|
# |536367;84879;ASSO...|
# |536367;22745;POPP...|
# |536367;22748;POPP...|
# |536367;22749;FELT...|
# |536367;22310;IVOR...|
# |536367;84969;BOX ...|
# |536367;22623;BOX ...|
# |536367;22622;BOX ...|
# |536367;21754;HOME...|
# |536367;21755;LOVE...|
# +--------------------+
# only showing top 20 rows

# %%
df_from_file = spark.read \
.option("sep",";") \
.option("header","True") \
.option("inferSchema","True") \
.csv("D:\\Datasets\\OnlineRetail.csv")

df_from_file.show(3)
# Out:
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|    InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|1.12.2010 08:26|     2,55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|1.12.2010 08:26|     3,39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|1.12.2010 08:26|     2,75|     17850|United Kingdom|
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# only showing top 3 rows

# %%
df_from_file.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- Country: string (nullable = true)

# %%
type(df_from_file)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pd = df_from_file.limit(5).toPandas()

# %%
type(df_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pd.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate UnitPrice  CustomerID         Country
# 0  1.12.2010 08:26      2,55       17850  United Kingdom
# 1  1.12.2010 08:26      3,39       17850  United Kingdom
# 2  1.12.2010 08:26      2,75       17850  United Kingdom
# 3  1.12.2010 08:26      3,39       17850  United Kingdom
# 4  1.12.2010 08:26      3,39       17850  United Kingdom

# %%
len(df_pd)
# Out:
# 5

# %%
df_from_file.count()
# Out:
# 541909

# %%
df_from_file.select("InvoiceNo","StockCode").show(10)
# Out:
# +---------+---------+
# |InvoiceNo|StockCode|
# +---------+---------+
# |   536365|   85123A|
# |   536365|    71053|
# |   536365|   84406B|
# |   536365|   84029G|
# |   536365|   84029E|
# |   536365|    22752|
# |   536365|    21730|
# |   536366|    22633|
# |   536366|    22632|
# |   536367|    84879|
# +---------+---------+
# only showing top 10 rows

# %%
df_from_file.sort("InvoiceNo").show(10)
# Out:
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|    InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# |   536365|    71053| WHITE METAL LANTERN|       6|1.12.2010 08:26|     3,39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|1.12.2010 08:26|     3,39|     17850|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|1.12.2010 08:26|     4,25|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|1.12.2010 08:26|     3,39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|1.12.2010 08:26|     2,75|     17850|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|1.12.2010 08:26|     7,65|     17850|United Kingdom|
# |   536365|   85123A|WHITE HANGING HEA...|       6|1.12.2010 08:26|     2,55|     17850|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|1.12.2010 08:28|     1,85|     17850|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|1.12.2010 08:28|     1,85|     17850|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|1.12.2010 08:34|     1,69|     13047|United Kingdom|
# +---------+---------+--------------------+--------+---------------+---------+----------+--------------+
# only showing top 10 rows

# %%
df_from_file.sort("InvoiceNo").explain()
# Out:
# == Physical Plan ==
# *(2) Sort [InvoiceNo#44 ASC NULLS FIRST], true, 0
# +- Exchange rangepartitioning(InvoiceNo#44 ASC NULLS FIRST, 200)
#    +- *(1) FileScan csv [InvoiceNo#44,StockCode#45,Description#46,Quantity#47,InvoiceDate#48,UnitPrice#49,CustomerID#50,Country#51] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/D:/Datasets/OnlineRetail.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<InvoiceNo:string,StockCode:string,Description:string,Quantity:int,InvoiceDate:string,UnitP...
